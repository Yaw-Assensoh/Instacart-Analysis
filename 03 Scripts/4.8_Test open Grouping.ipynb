# %%
import pandas as pd
import numpy as np
import os
from os.path import join

# %%
# importing files
path = r'/Users/kevinmcgreen/Documents/InstacartProject/03 Scripts/Prepared Data/orders_products_merged.pkl'

# %%
ords_prods_merged_df = pd.read_pickle('/Users/kevinmcgreen/Documents/InstacartProject/03 Scripts/Prepared Data/orders_products_merged.pkl')

# %%
ords_prods_merged_df.describe
# Out:
# <bound method NDFrame.describe of           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    0   2539329        1    prior             1          2
# 2                    0   2539329        1    prior             1          2
# 3                    0   2539329        1    prior             1          2
# 4                    0   2539329        1    prior             1          2
# ...                ...       ...      ...      ...           ...        ...
# 32434207       3421081   2977660   206209    prior            13          1
# 32434208       3421081   2977660   206209    prior            13          1
# 32434209       3421081   2977660   206209    prior            13          1
# 32434210       3421081   2977660   206209    prior            13          1
# 32434211       3421081   2977660   206209    prior            13          1
#
# ...

# %%
# create a subset 
df = ords_prods_merged_df[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             0   2539329        1    prior             1          2
# 2             0   2539329        1    prior             1          2
# 3             0   2539329        1    prior             1          2
# 4             0   2539329        1    prior             1          2
# 5             1   2398795        1    prior             2          3
# 6             1   2398795        1    prior             2          3
# 7             1   2398795        1    prior             2          3
# 8             1   2398795        1    prior             2          3
# 9             1   2398795        1    prior             2          3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                    -1.0         196                  1
# ...

# %%
# grouping
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.794722
# 2                17.091743
# 3                17.930716
# 4                17.892234
# 5                15.211405
# 6                15.382228
# 7                17.699986
# 8                16.485269
# 9                15.965921
# 10               20.091818
# 11               16.484907
# 12               15.615845
# 13               16.485279
# 14               17.499513
# 15               15.690354
# 16               18.005083
# 17               16.155822
# 18               19.606536
# 19               17.630640
# 20               17.138204
# 21               21.996844

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.794722
# 2     17.091743
# 3     17.930716
# 4     17.892234
# 5     15.211405
# 6     15.382228
# 7     17.699986
# 8     16.485269
# 9     15.965921
# 10    20.091818
# 11    16.484907
# 12    15.615845
# 13    16.485279
# 14    17.499513
# 15    15.690354
# 16    18.005083
# 17    16.155822
# 18    19.606536
# 19    17.630640
# 20    17.138204
# 21    21.996844
# Name: order_number, dtype: float64

# %%
# Another one
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     14.794722
# 2     17.091743
# 3     17.930716
# 4     17.892234
# 5     15.211405
# 6     15.382228
# 7     17.699986
# 8     16.485269
# 9     15.965921
# 10    20.091818
# 11    16.484907
# 12    15.615845
# 13    16.485279
# 14    17.499513
# 15    15.690354
# 16    18.005083
# 17    16.155822
# 18    19.606536
# 19    17.630640
# 20    17.138204
# 21    21.996844
# Name: order_number, dtype: float64

# %%
# Multiple aggregations
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.794722   1  99
# 2                17.091743   1  98
# 3                17.930716   1  99
# 4                17.892234   1  99
# 5                15.211405   1  99
# 6                15.382228   1  99
# 7                17.699986   1  99
# 8                16.485269   1  91
# 9                15.965921   1  99
# 10               20.091818   1  99
# 11               16.484907   1  99
# 12               15.615845   1  99
# 13               16.485279   1  99
# 14               17.499513   1  99
# 15               15.690354   1  99
# 16               18.005083   1  99
# 17               16.155822   1  99
# 18               19.606536   1  99
# 19               17.630640   1  99
# 20               17.138204   1  99
# 21               21.996844   1  97

# %%
# to transform
ords_prods_merged_df['max_order'] = ords_prods_merged_df.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/c3/vmr1w1q937z6kp6c42j805100000gn/T/ipykernel_8336/4019726567.py:2: FutureWarning: The provided callable <function max at 0x10d986480> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merged_df['max_order'] = ords_prods_merged_df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merged_df.head(15)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0              0   2539329        1    prior             1          2
# 1              0   2539329        1    prior             1          2
# 2              0   2539329        1    prior             1          2
# 3              0   2539329        1    prior             1          2
# 4              0   2539329        1    prior             1          2
# 5              1   2398795        1    prior             2          3
# 6              1   2398795        1    prior             2          3
# 7              1   2398795        1    prior             2          3
# 8              1   2398795        1    prior             2          3
# 9              1   2398795        1    prior             2          3
# 10             1   2398795        1    prior             2          3
# 11             2    473747        1    prior             3          3
# ...

# %%
# deriving columns 
ords_prods_merged_df.loc[ords_prods_merged_df['max_order'] > 40,
     'loyalty_flag'] = 'loyal customer'
ords_prods_merged_df.loc[(ords_prods_merged_df['max_order']<= 40) & (ords_prods_merged_df['max_order'] > 10),
     'loyalty_flag'] = 'Regular customer'  
ords_prods_merged_df.loc[ords_prods_merged_df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merged_df['loyalty_flag'].value_counts(dropna= False)
# Out:
# loyalty_flag
# Regular customer    15891077
# loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
ords_prods_merged_df[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...
