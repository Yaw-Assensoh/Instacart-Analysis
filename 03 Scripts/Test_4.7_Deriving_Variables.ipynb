# %% [markdown]
# # Deriving Variables

# %%
import pandas as pd
import numpy as np
import os
from os.path import join

# %%
path = r'/Users/kevinmcgreen/Documents/InstacartProject/03 Scripts/Prepared Data/orders_products_merged.pkl'

# %%
print(path)
# Out:
# /Users/kevinmcgreen/Documents/InstacartProject/03 Scripts/Prepared Data/orders_products_merged.pkl

# %%
ords_prods_merged_df = pd.read_pickle("/Users/kevinmcgreen/Documents/InstacartProject/03 Scripts/Prepared Data/orders_products_merged.pkl")

# %%
ords_prods_merged_df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             0   2539329        1    prior             1          2
# 2             0   2539329        1    prior             1          2
# 3             0   2539329        1    prior             1          2
# 4             0   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                    -1.0         196                  1
# 1                  8                    -1.0       14084                  2
# 2                  8                    -1.0       12427                  3
# 3                  8                    -1.0       26088                  4
# 4                  8                    -1.0       26405                  5
#
#    reordered _merge  Unnamed: 0_y                             product_name  \
# ...

# %%
ords_prods_merged_df.shape
# Out:
# (32434212, 17)

# %%
ords_prods_merged_df.columns
# Out:
# Index(['Unnamed: 0_x', 'order_id', 'user_id', 'eval_set', 'order_number',
#        'order_dow', 'order_hour_of_day', 'days_since_prior_order',
#        'product_id', 'add_to_cart_order', 'reordered', '_merge',
#        'Unnamed: 0_y', 'product_name', 'aisle_id', 'department_id', 'prices'],
#       dtype='object')

# %%
ords_prods_merged_df.info
# Out:
# <bound method DataFrame.info of           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    0   2539329        1    prior             1          2
# 2                    0   2539329        1    prior             1          2
# 3                    0   2539329        1    prior             1          2
# 4                    0   2539329        1    prior             1          2
# ...                ...       ...      ...      ...           ...        ...
# 32434207       3421081   2977660   206209    prior            13          1
# 32434208       3421081   2977660   206209    prior            13          1
# 32434209       3421081   2977660   206209    prior            13          1
# 32434210       3421081   2977660   206209    prior            13          1
# 32434211       3421081   2977660   206209    prior            13          1
#
# ...

# %%
ords_prods_merged_df.isnull().sum()
# Out:
# Unnamed: 0_x                  0
# order_id                      0
# user_id                       0
# eval_set                      0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order        0
# product_id                    0
# add_to_cart_order             0
# reordered                     0
# _merge                        0
# Unnamed: 0_y                  0
# product_name              28171
# aisle_id                      0
# department_id                 0
# prices                        0
# dtype: int64

# %%
# create a subset
df = ords_prods_merged_df[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
# Defiine a function
def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices']  > 5) and (row['prices'] <= 15):
        return 'Mid-tange product'
    elif row['prices'] > 15:
        return 'High range'
    else: return np.nan

# %%
# Apply function#
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/c3/vmr1w1q937z6kp6c42j805100000gn/T/ipykernel_4392/665422218.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-tange product    673471
# Low-range product    314116
# High range            12413
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
df.loc[df['prices'] > 15, 'prices_range_loc'] = 'High range product'
# Out:
# /var/folders/c3/vmr1w1q937z6kp6c42j805100000gn/T/ipykernel_4392/3008835225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'prices_range_loc'] = 'High range product'

# %%
df.loc[(df['prices']  <= 15) & (df['prices'] > 5),'price_range_loc'] = 'Mid range product'
# Out:
# /var/folders/c3/vmr1w1q937z6kp6c42j805100000gn/T/ipykernel_4392/4101692217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['prices']  <= 15) & (df['prices'] > 5),'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df['price_range_loc'].value_counts(dropna= False)
# Out:
# price_range_loc
# Mid range product    673471
# Low range product    314116
# NaN                   12413
# Name: count, dtype: int64

# %%
ords_prods_merged_df.loc[ords_prods_merged_df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged_df.loc[(ords_prods_merged_df['prices'] <= 15) & (ords_prods_merged_df['prices'] >5), 'prices_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged_df['price_range_loc'].value_counts(dropna= False)
# Out:
# price_range_loc
# NaN                   32016530
# High-range product      417682
# Name: count, dtype: int64

# %%
ords_prods_merged_df['order_dow'].value_counts(dropna= False)
# Out:
# order_dow
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %%
result = []
for value in ords_prods_merged_df["order_dow"]:
    if value ==0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...
