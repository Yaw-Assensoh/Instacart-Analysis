# %%
# Importing libraries
import pandas as pd 
import numpy as np
import os
from os.path import join

# %%
# Checking path
PREPARED_DATA_PATH = "../Prepared Data"

path = os.getcwd()

path =  '/Users/kevinmcgreen/Documents/InstacartProject/Scripts'

# %%
# import data
df_orders_products_combined = pd.read_pickle("Prepared Data/orders_products_combined.pkl")

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           0   2539329        1    prior             1          2
# 2           0   2539329        1    prior             1          2
# 3           0   2539329        1    prior             1          2
# 4           0   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                    -1.0         196                  1
# 1                  8                    -1.0       14084                  2
# 2                  8                    -1.0       12427                  3
# 3                  8                    -1.0       26088                  4
# 4                  8                    -1.0       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
# check for shape
df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
# import products wrangled clean 
df_products_wrangled = pd.read_csv("Prepared Data/products_wrangled.csv")

df_products_checked = pd.read_csv("Prepared Data/products_checked.csv")

products = pd.read_csv("Prepared Data/products_checked.csv")

# %%
# check output
df_products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# check output
df_products_wrangled.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# ## merging data frames

# %%
# checking for full match
df_merge = pd.merge (df_orders_products_combined, products, on = 'product_id')

# %%
df_merge
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    0   2539329        1    prior             1          2
# 2                    0   2539329        1    prior             1          2
# 3                    0   2539329        1    prior             1          2
# 4                    0   2539329        1    prior             1          2
# ...                ...       ...      ...      ...           ...        ...
# 32434207       3421081   2977660   206209    prior            13          1
# 32434208       3421081   2977660   206209    prior            13          1
# 32434209       3421081   2977660   206209    prior            13          1
# 32434210       3421081   2977660   206209    prior            13          1
# 32434211       3421081   2977660   206209    prior            13          1
#
# ...

# %%
# checking fo match counts
df_merge['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged = df_orders_products_combined.merge(products, on = 'product_id')

# %% [markdown]
# ## Exporting files

# %%
# export data to pickle
prepared_data_path = os.path.join(path, "Prepared Data")
os.makedirs(prepared_data_path, exist_ok=True)

df_merged.to_pickle(os.path.join(prepared_data_path, "orders_products_merged.pkl"))

# %%
path = os.getcwd()

# %%
df_merged = "orders_products_merged"
